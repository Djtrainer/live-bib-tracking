# %%
import os
from pathlib import Path
# from src.dataloader import DataLoader

ROOT = Path(os.getcwd()).parents[0]

ROOT
# Out:
# PosixPath('/Users/dantrainer/projects/live-bib-tracking')

# %%
def move_json_files(source_dir, target_dir="./labels"):
    """
    Scans a directory and moves all .json files to a target directory.

    Args:
        source_dir (str): The directory to scan for .json files.
        target_dir (str): The directory where .json files will be moved. Defaults to './labels'.
    """
    os.makedirs(target_dir, exist_ok=True)  # Create the target directory if it doesn't exist

    for file_name in os.listdir(source_dir):
        if file_name.endswith(".json"):
            source_path = os.path.join(source_dir, file_name)
            target_path = os.path.join(target_dir, file_name)
            os.rename(source_path, target_path)  # Move the file

data_path = os.path.join(ROOT, "data", "processed","frames")

move_json_files(data_path, target_dir=os.path.join(ROOT, "data", "processed", "labels"))

# %%
import os
import json
from glob import glob

# Paths
labelme_dir = os.path.join(ROOT, "data", "processed", "annotations")
output_dir = os.path.join(ROOT, "data", "processed", "labels")
os.makedirs(output_dir, exist_ok=True)

# Loop over JSON files
for json_file in glob(os.path.join(labelme_dir, "*.json")):
    with open(json_file, "r") as f:
        data = json.load(f)

    img_w = data["imageWidth"]
    img_h = data["imageHeight"]

    yolo_lines = []
    for shape in data["shapes"]:
        label = int(shape["label"])  # assuming labels are numeric in your JSON

        # LabelMe rectangle has two points: top-left and bottom-right
        (x1, y1), (x2, y2) = shape["points"]

        # Calculate YOLO format
        x_center = ((x1 + x2) / 2) / img_w
        y_center = ((y1 + y2) / 2) / img_h
        width = abs(x2 - x1) / img_w
        height = abs(y2 - y1) / img_h

        yolo_lines.append(f"{label} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}")

    # Save .txt with same base name as the image
    base_name = os.path.splitext(os.path.basename(data["imagePath"]))[0]
    txt_path = os.path.join(output_dir, f"{base_name}.txt")

    with open(txt_path, "w") as out_f:
        out_f.write("\n".join(yolo_lines))

    print(f"Converted {json_file} → {txt_path}")

print(f"\n✅ Done. YOLO labels saved in '{output_dir}'")
# Out:
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00876.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00876.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00437.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00437.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00421.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00421.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00564.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00564.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00163.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00163.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00266.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00266.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00159.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00159.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00591.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00591.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00657.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00657.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00180.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00180.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00303.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00303.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00397.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00397.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00790.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00790.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00913.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00913.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00695.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00695.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00553.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00553.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00912.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00912.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00791.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00791.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00457.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00457.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00396.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00396.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00050.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00050.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00400.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00400.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00617.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00617.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00302.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00302.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00181.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00181.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00590.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00590.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00676.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00676.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00267.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00267.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00162.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00162.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00135.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00135.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00565.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00565.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00359.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00359.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00436.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00436.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00524.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00524.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00877.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00877.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00485.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00485.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00201.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00201.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00352.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00352.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00450.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00450.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00329.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00329.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00283.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00283.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00446.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00446.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00915.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00915.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00295.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00295.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00554.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00554.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00870.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00870.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00173.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00173.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00523.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00523.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00348.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00348.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00718.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00718.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00974.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00974.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00667.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00667.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00333.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00333.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00626.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00626.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00558.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00558.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00918.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00918.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00332.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00332.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00627.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00627.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00774.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00774.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00666.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00666.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00975.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00975.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00172.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00172.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00555.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00555.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00447.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00447.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00914.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00914.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00282.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00282.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00797.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00797.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00056.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00056.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00241.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00241.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00353.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00353.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00200.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00200.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00556.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00556.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00628.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00628.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00917.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00917.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00444.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00444.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00281.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00281.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00844.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00844.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00669.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00669.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00055.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00055.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00242.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00242.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00645.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00645.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00254.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00254.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00604.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00604.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00487.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00487.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00673.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00673.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00366.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00366.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00448.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00448.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00624.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00624.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00331.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00331.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00798.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00798.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00219.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00219.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00023.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00023.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00799.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00799.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00625.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00625.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00330.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00330.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00449.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00449.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00486.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00486.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00644.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00644.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00869.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00869.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00306.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00306.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00054.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00054.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00668.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00668.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00003.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00003.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00845.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00845.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00280.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00280.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00916.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00916.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00445.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00445.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00629.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00629.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00279.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00279.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00296.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00296.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00557.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00557.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00049.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00049.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00360.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00360.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00399.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00399.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00376.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00376.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00161.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00161.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00618.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00618.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00136.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00136.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00566.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00566.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00423.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00423.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00435.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00435.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00198.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00198.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00696.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00696.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00442.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00442.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00854.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00854.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00141.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00141.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00842.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00842.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00395.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00395.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00546.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00546.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00301.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00301.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00182.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00182.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00252.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00252.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00253.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00253.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00603.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00603.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00183.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00183.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00052.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00052.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00547.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00547.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00843.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00843.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00443.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00443.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00855.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00855.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00697.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00697.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00199.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00199.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00658.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00658.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00988.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00988.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00137.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00137.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00567.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00567.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00422.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00422.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00160.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00160.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00398.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00398.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00377.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00377.txt
# Converted /Users/dantrainer/projects/live-bib-tracking/data/processed/annotations/frame_00361.json → /Users/dantrainer/projects/live-bib-tracking/data/processed/labels/frame_00361.txt
#
# ✅ Done. YOLO labels saved in '/Users/dantrainer/projects/live-bib-tracking/data/processed/labels'

# %%
import os
import json
import torch
from torch.utils.data import Dataset

from PIL import Image


class ObjectDetectionDataset(Dataset):
    """Dataset for object detection tasks with images and annotations."""
    def __init__(self, root_dir, transform=None, test=True):
        self.root_dir = root_dir
        self.transform = transform
        self.image_files = []
        self.annotation_files = []
        self.test = test

        # Populate image and annotation file lists
        for filename in os.listdir(root_dir):
            if not filename.endswith(".json") and not self.test:
                continue

            root_filename = filename.split(".")[0]

            image_file = os.path.join(root_dir, root_filename + ".jpg")
            annotation_file = os.path.join(root_dir, filename)

            if os.path.exists(image_file):
                self.image_files.append(image_file)
                self.annotation_files.append(annotation_file)

    def _read_and_validate_annotation_file(json_file):
        with open(json_file, "r") as file:
            annotation_file = json.load(file)

        shapes = annotation_file["shapes"]

        assert len(shapes) == 2, "more than 2 labels provided"
        assert "0" in [x["label"] for x in shapes], "no grid label provided"
        assert "1" in [x["label"] for x in shapes], "no cross hair label provided"

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        img = Image.open(img_path).convert("RGB")
        initial_size = img.size

        annotation_path = self.annotation_files[idx]
        boxes = []
        labels = []
        filename = img_path.split("/")[-1]
        if not self.test:
            with open(annotation_path, "r") as file:
                annotations = json.load(file)

            for line in annotations["shapes"]:
                boxes.append(line["points"])
                labels.append(int(line["label"]))

            boxes = torch.tensor(boxes, dtype=torch.float32)
            labels = torch.tensor(labels, dtype=torch.int64)

            cross_hair_box = boxes[1]

            x1 = cross_hair_box[0, 0]
            y1 = cross_hair_box[0, 1]
            x2 = cross_hair_box[1, 0]
            y2 = cross_hair_box[1, 1]

            x_box = torch.tensor(((x1, 0), (x2, img.size[1])))
            y_box = torch.tensor(((0, y1), (img.size[0], y2)))

            boxes = torch.stack((boxes[0], x_box, y_box))
            labels = torch.concat((labels, torch.tensor((2,))))

        if self.transform:
            img = self.transform(img)
            resized_shape = img.size()
            scale_factor = initial_size[0] / resized_shape[2]

            if len(boxes) != 0:
                boxes /= scale_factor

        return img, boxes, labels, filename

# %%
data_path = os.path.join(ROOT, "data", "processed","frames")
train_dataset = ObjectDetectionDataset(data_path, test=False)

# %%
img, boxes, labels, filename = train_dataset.__getitem__(-1)

# %%
img, boxes, labels, filename
# Out:
# (<PIL.Image.Image image mode=RGB size=3840x2160>,
#  tensor([[[2801.9148,  791.7021],
#           [3418.9363, 2147.0212]],
#
#          [[3095.5320,    0.0000],
#           [3263.6169, 2160.0000]],
#
#          [[   0.0000, 1302.3405],
#           [3840.0000, 1451.2766]]]),
#  tensor([0, 1, 0, 0, 2, 2, 1, 2]),
#  'frame_00361.jpg')
